# %%
#test to see if file is defined. This test should fail.
file.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b95781cf6aa3> in <module>()
# ----> 1 file.read()
#
# NameError: name 'file' is not defined

# %%
#defining 'file' as a TPS file in my folder
file = open('/home/admin736/Desktop/share-git/sandbox-1/nbir012-diptera-morpho/geo-morph-data.TPS','r')

# %%
#opening up the file
file.read()
# Out:
# 'LM=23\n1423.00000 2235.00000\n2924.00000 1762.00000\n3351.00000 1467.00000\n3449.00000 1319.00000\n3045.00000 994.00000\n2884.00000 992.00000\n2731.00000 1017.00000\n2471.00000 1053.00000\n2304.00000 1055.00000\n1918.00000 1164.00000\n1893.00000 1225.00000\n1337.00000 2131.00000\n1868.00000 1601.00000\n1993.00000 1592.00000\n2022.00000 1628.00000\n2365.00000 1371.00000\n2515.00000 1371.00000\n2553.00000 1417.00000\n2833.00000 1405.00000\n1971.00000 1818.00000\n2113.00000 1781.00000\n2144.00000 1831.00000\n2099.00000 1933.00000\nIMAGE=DSC_7852.JPG\nID=0 \nLM=23\n2512.00000 2198.00000\n2858.00000 1218.00000\n2875.00000 675.00000\n2823.00000 541.00000\n2458.00000 666.00000\n2366.00000 781.00000\n2289.00000 889.00000\n2209.00000 1061.00000\n2163.00000 1176.00000\n2080.00000 1404.00000\n2115.00000 1497.00000\n2418.00000 2213.00000\n2360.00000 1672.00000\n2397.00000 1607.00000\n2427.00000 1592.00000\n2387.00000 1263.00000\n2452.00000 1172.00000\n2505.00000 1175.00000\n2623.00000 961.00000\n2500.00000 1678.00000\n2544.00000 1585.00000\n2585.00000 1592.00000\n2633.00000 1672.00000\nIMAGE=DSC_7855.JPG\nID=2 \nLM=23\n1440.00000 1732.00000\n2718.00000 1749.00000\n3286.00000 1601.00000\n3369.00000 1527.00000\n3114.00000 1190.00000\n2960.00000 1138.00000\n2807.00000 1074.00000\n2663.00000 1044.00000\n2557.00000 1023.00000\n2253.00000 1006.00000\n2208.00000 1060.00000\n1383.00000 1645.00000\n2005.00000 1396.00000\n2085.00000 1418.00000\n2096.00000 1430.00000\n2458.00000 1294.00000\n2541.00000 1340.00000\n2541.00000 1386.00000\n2858.00000 1403.00000\n2010.00000 1548.00000\n2129.00000 1541.00000\n2149.00000 1600.00000\n2086.00000 1656.00000\nIMAGE=DSC_7858.JPG\nID=3 \nLM=23\n1080.00000 2096.00000\n2908.00000 2176.00000\n3836.00000 2017.00000\n3987.00000 1933.00000\n3606.00000 1352.00000\n3385.00000 1243.00000\n3138.00000 1168.00000\n2891.00000 1109.00000\n2719.00000 1084.00000\n2180.00000 1063.00000\n2138.00000 1113.00000\n979.00000 1925.00000\n1833.00000 1599.00000\

# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-2910c7c61713> in <module>()
# ----> 1 len(file)
#
# TypeError: object of type '_io.TextIOWrapper' has no len()

# %%
array = [] #create empty array
with open('/home/admin736/Desktop/share-git/sandbox-1/nbir012-diptera-morpho/geo-morph-data.TPS','r') as file: #define file and open required tps file
    for line in file: #create loop using each line (string) within the file
        line = line.strip('\r\n') #define line by removing the newline fluff (\r\n)
        array.append(line) #append (add) the outcome into the original blank array we created above.
        
values = array[1923].split(' ') #defining values as individual components in the array split by blank space
splits = "" #defining splits as blank space
for splitValues in values: #creating a loop which splits the values within 
    splits = splits + splitValues
    print(splitValues)
len(array) #print how many variables there are inside the array
# Out:
# ID=106
# 1924

# %%
#for line in file:
    line.split ('')
    print(line)
# Out:
#   File "<ipython-input-10-4929c629117c>", line 2
#     line.split ('')
#     ^
# IndentationError: unexpected indent

# %%
#Test one to see if 0th array component is equal to the first piece of information in the .TPS file
array = [] #create empty array
with open('/home/admin736/Desktop/share-git/sandbox-1/nbir012-diptera-morpho/geo-morph-data.TPS','r') as file: #define file and open required tps file
    for line in file: #create loop using each line (string) within the file
        line = line.strip('\r\n') #define line by removing the newline fluff (\r\n)
        array.append(line) #append (add) the outcome into the original blank array we created above.
                
values = array[0].split(' ') #defining values as individual components in the array split by blank space this takes the 0th one
splits = "" #defining splits as blank space
for splitValues in values: #creating a loop which splits the values within 
    splits = splits + splitValues
    print(splitValues)
    
if splitValues == 'LM=23':
    print('Test Passed')
else:
    print('Test Failed')
# Out:
# LM=23
# Test Passed

# %%
#Test two to see if the last variable (no. 1923) is the same as what is shown in the tps file
array = [] #create empty array
with open('/home/admin736/Desktop/share-git/sandbox-1/nbir012-diptera-morpho/geo-morph-data.TPS','r') as file: #define file and open required tps file
    for line in file: #create loop using each line (string) within the file
        line = line.strip('\r\n') #define line by removing the newline fluff (\r\n)
        array.append(line) #append (add) the outcome into the original blank array we created above.
                
values = array[1923].split(' ') #defining values as individual components in the array split by blank space this takes the 0th one
splits = "" #defining splits as blank space
for splitValues in values: #creating a loop which splits the values within 
    splits = splits + splitValues
    print(splitValues)
    
if splitValues == 'ID=106':
    print('Test Passed')
else:
    print('Test Failed')
# Out:
# ID=106
#
# Test Failed

# %%
#Test three to see if the last variable (no. 1923) is the same as what is shown in the tps file
array = [] #create empty array
with open('/home/admin736/Desktop/share-git/sandbox-1/nbir012-diptera-morpho/geo-morph-data.TPS','r') as file: #define file and open required tps file
    for line in file: #create loop using each line (string) within the file
        line = line.strip('\r\n') #define line by removing the newline fluff (\r\n)
        array.append(line) #append (add) the outcome into the original blank array we created above.
                
values = array[961].split(' ') #defining values as individual components in the array split by blank space this takes the 0th one
splits = "" #defining splits as blank space
for splitValues in values: #creating a loop which splits the values within 
    splits = splits + splitValues
    print(splitValues)
    
if splitValues == 'ID=40':
    print('Test Passed')
else:
    print('Test Failed')
# Out:
# ID=40
#
# Test Failed
